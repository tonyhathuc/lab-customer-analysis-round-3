# %%
# import libraries

import pandas as pd
import numpy as np

# %%
# import csv file
data=pd.read_csv('marketing_customer_analysis.csv')    

# show first 5 rows

data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %% [markdown]
# ## 1) Show the dataframe shape

# %%
df = data
df.shape
# Out:
# (9134, 24)

# %%
df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %% [markdown]
# ## 2) Standardize Header Names

# %%
# column names
df.columns

# lower the column names and replace whitespaces with _'s
df.columns=[column.lower().replace(' ', '_') for column in df.columns]

df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# ## 3) Which columns are numerical?

# %%
# start with an overview

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %% [markdown]
# ## 4) Which columns are categorical?

# %%
# take the numerical column names
# drop them from original dataframe
# we should get only categoricals

df.drop(columns=df._get_numeric_data().columns).columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective_to_date', 'employmentstatus', 'gender', 'location_code',
#        'marital_status', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# ## 5) Check and deal with NaN values

# %%
df.isna().sum()

# It's all clean!
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %% [markdown]
# ## 6) Datetime format
# Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie Jan Feb and March

# %%
# check dtype


df['effective_to_date'].dtype
# Out:
# dtype('O')

# %%
df['effective_to_date']
# Out:
# 0       2/24/11
# 1       1/31/11
# 2       2/19/11
# 3       1/20/11
# 4        2/3/11
#          ...
# 9129    2/10/11
# 9130    2/12/11
# 9131     2/6/11
# 9132     2/3/11
# 9133    2/14/11
# Name: effective_to_date, Length: 9134, dtype: object

# %%
# use to_datetime() function
# this is just a query

pd.to_datetime(df['effective_to_date'],
               errors='raise')
# Out:
# 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-02-03
#           ...
# 9129   2011-02-10
# 9130   2011-02-12
# 9131   2011-02-06
# 9132   2011-02-03
# 9133   2011-02-14
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %%
# now we store it into separate column

df['effective_to_date'] = pd.to_datetime(df['effective_to_date'], errors='raise')

# %%
# check dtype

data['effective_to_date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Extracting the month from that column

# %%
df['effective_to_date_month'] = df['effective_to_date'].dt.month
df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                         0                  1  Corporate Auto  Corporate L3
# ...

# %% [markdown]
# ## Show first quarter only

# %%
# use the built-in function to determine the quarter of datetime entries in a column
# Jan, Feb, Mar belong to quarter 1

df[df['effective_to_date'].dt.quarter == 1]
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
q1_df = df[df['effective_to_date'].dt.quarter == 1]
q1_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
q1_df['effective_to_date_month'].value_counts()
# Out:
# 1    4898
# 2    4236
# Name: effective_to_date_month, dtype: int64

# %%
df['effective_to_date_month'].value_counts()
# Out:
# 1    4898
# 2    4236
# Name: effective_to_date_month, dtype: int64

# %%
df.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %% [markdown]
# ## Import libraries for plotting

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Show a plot of the total number of responses broken down by response kind

# %%
data['response'].value_counts().plot(kind='bar');

# %%
# with seaborn
sns.countplot(data=data,x='response',hue='sales_channel')
# Out:
# <AxesSubplot:xlabel='response', ylabel='count'>

# %% [markdown]
# ### Show a plot of the distribution of the total claim amount, broken down by response kind.
# - Try a boxplot and distribution plot, for each response kind.
# - For the distribution plot, try to plot both kinds of responses in one chart
# (you can try with seaborn's histplot, using the hue parameter)

# %% [raw]
# sns.boxplot( x=data["response"], y=data["total_claim_amount"])

# %%
sns.distplot(x=data[['total_claim_amount']][data['response']=='Yes']);
plt.xlim(-10, 1500)
# Out:
# C:\Users\digit\anaconda3\envs\excondables\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (-10.0, 1500.0)

# %%
sns.distplot(x=data[['total_claim_amount']][data['response']=='No']);
plt.xlim(-10, 1500)
# Out:
# C:\Users\digit\anaconda3\envs\excondables\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (-10.0, 1500.0)

# %%
sns.histplot(data=data, x="total_claim_amount", hue="response")
plt.xlim(-10, 1500)
# Out:
# (-10.0, 1500.0)

# %% [markdown]
# ## Create similar plots like in the task before, but for Income

# %%
sns.histplot(data=data, x="income", hue="response")
# Out:
# <AxesSubplot:xlabel='income', ylabel='Count'>

# %%
sns.boxplot( x=data["response"], y=data["income"] )
# Out:
# <AxesSubplot:xlabel='response', ylabel='income'>

# %% [markdown]
# ## Create a scatterplot between total claim amount and income.
# Play around with the parameters of the scatterplot <br>
# (markersize? alpha?) and try to identify more features within the data just visually. <br>
# You can also try different seaborn plots.

# %%
plt.figure(figsize=(16, 10))
#fig,axe=plt.subplots()
plt.title("Total Claim amount vs Income")
claimvsincome = sns.scatterplot(data=data, x="income", y="total_claim_amount",s=200, alpha = .1)
claimvsincome;

# %% [markdown]
# ## Interesting insights from this visualization:
# - Strong tendency of claims when the customer has no income
# - Empty data under 10000 dollars of wage, the company could have a policy to not accept customers under that threshold
# - Horizontal line circa 350 dollar claims, could indicate a "Standard" compensation amount the company is giving out
